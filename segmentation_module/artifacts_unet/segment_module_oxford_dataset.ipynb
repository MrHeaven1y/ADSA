# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("devdgohil/the-oxfordiiit-pet-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 780M/780M [00:39<00:00, 20.8MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/devdgohil/the-oxfordiiit-pet-dataset/versions/2

# %%
import importlib
import os
import zipfile
import train_seg_unet

importlib.reload(train_seg_unet)
# Out:
# <module 'train_seg_unet' from '/content/train_seg_unet.py'>

# %%
img_path = os.path.join(path, "images/images")

# %%
len(os.listdir(img_path))
# Out:
# 7393

# %%
train_seg_unet.generate_masks(
    weights_path="/content/best_weights.pth",
    img_dir=img_path,
    out_mask_dir="/content/masks",
    device="cuda",
    img_size=224,
    threshold=0.5
)
# Out:
#   Generating masks for 7390 images → /content/masks
#   Done.

# %%
def make_zip(src_dir, dest_zip):

    if os.path.exists(src_dir):
        print(f"Zipping contents of {src_dir}...\n")

        with zipfile.ZipFile(dest_zip, 'w', zipfile.ZIP_DEFLATED) as zipf:
            for root, dirs, files in os.walk(src_dir):
                for file in files:
                    file_path = os.path.join(root, file)

                    arcname = os.path.relpath(file_path, src_dir)

                    zipf.write(file_path, arcname)

        print("Done!")

    else:
        print(f"Source directory {src_dir} does not exist!")
        return

    print("\n📦 Zip file created:")
    print(dest_zip)


make_zip("/content/masks", "oxford_pet_dataset_masks(unet).zip")
# Out:
# Zipping contents of /content/masks...
#
# Done!
#
# 📦 Zip file created:
# oxford_pet_dataset_masks(unet).zip

# %%
len(os.listdir('/content/masks'))
# Out:
# 7390
